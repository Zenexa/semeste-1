# %%
student_data = {
    "student_data_1":{
        "student_number":101,
        "name": "Andri", 
        "subjects": {"Programming Basic": 80, "Web Programming": 70},
    },
    
    "student_data_2":{
        "student_number":102,
        "name": "Budi", 
        "subjects": {"Programming Basic": 90, "Web Programming": 80}
    },
    
    "student_data_3":{
        "student_number":103,
        "name": "Cika", 
        "subjects": {"Programming Basic": 100, "Web Programming": 80}
    },
    
    "student_data_4":{
        "student_number":104,
        "name": "Dedi", 
        "subjects": {"Programming Basic": 100, "Web Programming": 90}
    },
    
    
    "student_data_5":{
        "student_number":105,
        "name": "Eka", 
        "subjects": {"Programming Basic": 50, "Web Programming": 90}
    },
    
    
    "student_data_6":{
        "student_number":106,
        "name": "Eka", 
        "subjects": {"Programming Basic": 40, "Web Programming": 60}
    },
    
    "student_data_7":{
        "student_number":107,
        "name": "Galih", 
        "subjects": {"Programming Basic": 70, "Web Programming": 95}
    },
    
    "student_data_8":{
        "student_number":108,
        "name": "Huda", 
        "subjects": {"Programming Basic": 70, "Web Programming": 85}
    },
    
    "student_data_9":{
        "student_number":109,
        "name": "Intan", 
        "subjects": {"Programming Basic": 60, "Web Programming": 90}
    },
    
}



for student_id, student_info in student_data.items():
    for subject, grade in student_info['subjects'].items():
        print(grade)
# Out:
# 80
# 70
# 90
# 80
# 100
# 80
# 100
# 90
# 50
# 90
# 40
# 60
# 70
# 95
# 70
# 85
# 60
# 90

# %%
student_data = {
    "student_data_1":{
        "student_number":101,
        "name": "Andri", 
        "subjects": {"Programming Basic": 80, "Web Programming": 70},
    },
    
    "student_data_2":{
        "student_number":102,
        "name": "Budi", 
        "subjects": {"Programming Basic": 90, "Web Programming": 80}
    },
    
    "student_data_3":{
        "student_number":103,
        "name": "Cika", 
        "subjects": {"Programming Basic": 100, "Web Programming": 80}
    },
    
    "student_data_4":{
        "student_number":104,
        "name": "Dedi", 
        "subjects": {"Programming Basic": 100, "Web Programming": 90}
    },
    
    
    "student_data_5":{
        "student_number":105,
        "name": "Eka", 
        "subjects": {"Programming Basic": 50, "Web Programming": 90}
    },
    
    
    "student_data_6":{
        "student_number":106,
        "name": "Eka", 
        "subjects": {"Programming Basic": 40, "Web Programming": 60}
    },
    
    "student_data_7":{
        "student_number":107,
        "name": "Galih", 
        "subjects": {"Programming Basic": 70, "Web Programming": 95}
    },
    
    "student_data_8":{
        "student_number":108,
        "name": "Huda", 
        "subjects": {"Programming Basic": 70, "Web Programming": 85}
    },
    
    "student_data_9":{
        "student_number":109,
        "name": "Intan", 
        "subjects": {"Programming Basic": 60, "Web Programming": 90}
    },
    
}

print(len(student_data.items()))
for student_id, student_info in student_data.items():
    for subject, grade in student_info['subjects'].items():
        if grade > 80:
            print(f" Student number: {student_info['student_number']} \n Student Name: {student_info['name']} \n Subject: {subject} \n Grade: {grade} \n")
# Out:
# 9
#  Student number: 102
#  Student Name: Budi
#  Subject: Programming Basic
#  Grade: 90
#
#  Student number: 103
#  Student Name: Cika
#  Subject: Programming Basic
#  Grade: 100
#
#  Student number: 104
#  Student Name: Dedi
#  Subject: Programming Basic
#  Grade: 100
#
#  Student number: 104
#  Student Name: Dedi
#  Subject: Web Programming
#  Grade: 90
#
#  Student number: 105
#  Student Name: Eka
#  Subject: Web Programming
#  Grade: 90
#
#  Student number: 107
#  Student Name: Galih
#  Subject: Web Programming
#  Grade: 95
#
#  Student number: 108
#  Student Name: Huda
#  Subject: Web Programming
#  Grade: 85
#
#  Student number: 109
#  Student Name: Intan
#  Subject: Web Programming
#  Grade: 90

# %%
student_data = {
    "student_data_1":{
        "student_number":101,
        "name": "Andri", 
        "subjects": {"Programming Basic": 80, "Web Programming": 70},
    },
    
    "student_data_2":{
        "student_number":102,
        "name": "Budi", 
        "subjects": {"Programming Basic": 90, "Web Programming": 80}
    },
    
    "student_data_3":{
        "student_number":103,
        "name": "Cika", 
        "subjects": {"Programming Basic": 100, "Web Programming": 80}
    },
    
    "student_data_4":{
        "student_number":104,
        "name": "Dedi", 
        "subjects": {"Programming Basic": 100, "Web Programming": 90}
    },
    
    
    "student_data_5":{
        "student_number":105,
        "name": "Eka", 
        "subjects": {"Programming Basic": 50, "Web Programming": 90}
    },
    
    
    "student_data_6":{
        "student_number":106,
        "name": "Eka", 
        "subjects": {"Programming Basic": 40, "Web Programming": 60}
    },
    
    "student_data_7":{
        "student_number":107,
        "name": "Galih", 
        "subjects": {"Programming Basic": 70, "Web Programming": 95}
    },
    
    "student_data_8":{
        "student_number":108,
        "name": "Huda", 
        "subjects": {"Programming Basic": 70, "Web Programming": 85}
    },
    
    "student_data_9":{
        "student_number":109,
        "name": "Intan", 
        "subjects": {"Programming Basic": 60, "Web Programming": 90}
    },
    
}

# for key, value in student_data.items():
#     student_avg = value["subjects"]["Programming Basic"]
#     student_avg2 = value["subjects"]["Web Programming"]
#     if student_avg > 80 and student_avg2 > 80:
#         print(student_avg,student_avg2)
        
print(len(student_data[]))
        
# for key, value in student_data.items():
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 66
#       1 student_data = {
#       2     "student_data_1":{
#       3         "student_number":101,
#    (...)
#      57
#      58 }
#      60 # for key, value in student_data.items():
#      61 #     student_avg = value["subjects"]["Programming Basic"]
#      62 #     student_avg2 = value["subjects"]["Web Programming"]
#      63 #     if student_avg > 80 and student_avg2 > 80:
#      64 #         print(student_avg,student_avg2)
# ---> 66 print(len(student_data["subjects"].items()))
#      68 # for key, value in student_data.items():
#
# KeyError: 'subjects'
