# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd


xpoints = np.array([10,20,30,40,50])
ypoints = np.array([1,2,3,4,5])

plt.plot(xpoints,ypoints)
plt.show()

# %%
data = pd.read_csv('https://raw.githubusercontent.com/Zenexa/semeste-1/main/13.SESI%2015/Data_siswa_unp.csv')
data
# Out:
#   Jurusan  Jumlah
# 0      TI    1000
# 1      SI     800
# 2      AK    1100
# 3      TE     500
# 4      MJ    2000
# 5      HK     400
# 6     DKV     300
# 7    PGSD     500
# 8      MS     200

# %%
plt.pie(data['Jumlah'],labels = data['Jurusan'])
plt.show()
